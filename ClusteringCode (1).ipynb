# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("smartcart_customers.csv")
df.head()
# Out:
#      ID  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0  5524        1957  Graduation         Single  58138.0        0         0
# 1  2174        1954  Graduation         Single  46344.0        1         1
# 2  4141        1965  Graduation       Together  71613.0        0         0
# 3  6182        1984  Graduation       Together  26646.0        1         0
# 4  5324        1981         PhD        Married  58293.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0  04-09-2012       58       635  ...              172                88
# 1  08-03-2014       38        11  ...                2                 1
# 2  21-08-2013       26       426  ...              111                21
# 3  10-02-2014       26        11  ...               10                 3
# 4  19-01-2014       94       173  ...               46                27
#
#    MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# ...

# %% [markdown]
# ## Data Preprocessing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# ID                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# Complain                0
# Response                0
# dtype: int64

# %%
Median_Income=df["Income"].median()
print(Median_Income)
# Out:
# 51381.5

# %%
# Handling Missing Values
df["Income"]=df["Income"].fillna(Median_Income)

# %%
df.isnull().sum()
# Out:
# ID                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# Complain               0
# Response               0
# dtype: int64

# %%
df["Education"].value_counts()
# Out:
# Education
# Graduation    1127
# PhD            486
# Master         370
# 2n Cycle       203
# Basic           54
# Name: count, dtype: int64

# %%
df["Marital_Status"].value_counts()
# Out:
# Marital_Status
# Married     864
# Together    580
# Single      480
# Divorced    232
# Widow        77
# Alone         3
# Absurd        2
# YOLO          2
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#                  ID   Year_Birth         Income      Kidhome     Teenhome  \
# count   2240.000000  2240.000000    2240.000000  2240.000000  2240.000000
# mean    5592.159821  1968.805804   52237.975446     0.444196     0.506250
# std     3246.662198    11.984069   25037.955891     0.538398     0.544538
# min        0.000000  1893.000000    1730.000000     0.000000     0.000000
# 25%     2828.250000  1959.000000   35538.750000     0.000000     0.000000
# 50%     5458.500000  1970.000000   51381.500000     0.000000     0.000000
# 75%     8427.750000  1977.000000   68289.750000     1.000000     1.000000
# max    11191.000000  1996.000000  666666.000000     2.000000     2.000000
#
#            Recency     MntWines    MntFruits  MntMeatProducts  \
# count  2240.000000  2240.000000  2240.000000      2240.000000
# mean     49.109375   303.935714    26.302232       166.950000
# std      28.962453   336.597393    39.773434       225.715373
# ...

# %% [markdown]
# ### Feature Engineering

# %%
df.columns
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'Complain', 'Response'],
#       dtype='object')

# %%
# New feature 1 - Age
df["Age"]=2026-df["Year_Birth"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2240 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
df["Dt_Customer"]=pd.to_datetime(df["Dt_Customer"],dayfirst=True)

# %%
# New Feature 2 - Customer Tensure
# we could have taken the present date and time but it will change every time we run the code
reference_date=df["Dt_Customer"].max() 
df["Customer_Tenure_Days"]=(reference_date-df["Dt_Customer"]).dt.days

# %%
df.columns
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'Complain', 'Response', 'Age', 'Customer_Tenure_Days'],
#       dtype='object')

# %%
# New Feature 3 - Overall Spending
df["Total_Spending"]=df["MntWines"]+df["MntFruits"]+df["MntGoldProds"]+df["MntMeatProducts"]+df["MntSweetProducts"]+df["MntFishProducts"]

# %%
# New Feature 4 - Total Children
df["Total_Children"]=df["Kidhome"]+df["Teenhome"]

# %%
df["Education"]=df["Education"].replace({"Education":"Graduate","PhD":"Postgraduate","Master":"Postgraduate","2n Cycle":"Undergraduate","Basic":"Undergraduate"})
df["Education"].value_counts()
# Out:
# Education
# Graduation       1127
# Postgraduate      856
# Undergraduate     257
# Name: count, dtype: int64

# %%
df["Living_with"]=df["Marital_Status"].replace({"Married":"Partner","Together":"Partner","Single":"Alone","Divorced":"Alone","Widow":"Alone","Absurd":"Alone","YOLO":"Alone"})

# %%
df["Living_with"].value_counts()
# Out:
# Living_with
# Partner    1444
# Alone       796
# Name: count, dtype: int64

# %% [markdown]
# ### Drop Columns

# %%
df.columns
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'Complain', 'Response', 'Age', 'Customer_Tenure_Days', 'Total_Spending',
#        'Total_Children', 'Living_with'],
#       dtype='object')

# %%
df_cleaned=df.drop(columns=['ID','Year_Birth','Marital_Status','Kidhome',
       'Teenhome', 'Dt_Customer','MntWines', 'MntFruits',
       'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
       'MntGoldProds'])

# %%
df_cleaned.shape
# Out:
# (2240, 15)

# %%
df_cleaned.head()
# Out:
#       Education   Income  Recency  NumDealsPurchases  NumWebPurchases  \
# 0    Graduation  58138.0       58                  3                8
# 1    Graduation  46344.0       38                  2                1
# 2    Graduation  71613.0       26                  1                8
# 3    Graduation  26646.0       26                  2                2
# 4  Postgraduate  58293.0       94                  5                5
#
#    NumCatalogPurchases  NumStorePurchases  NumWebVisitsMonth  Complain  \
# 0                   10                  4                  7         0
# 1                    1                  2                  5         0
# 2                    2                 10                  4         0
# 3                    0                  4                  6         0
# 4                    3                  6                  5         0
#
#    Response  Age  Customer_Tenure_Days  Total_Spending  Total_Children  \
# ...

# %% [markdown]
# ### Outliers

# %%
df_cleaned.columns
# Out:
# Index(['Education', 'Income', 'Recency', 'NumDealsPurchases',
#        'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases',
#        'NumWebVisitsMonth', 'Complain', 'Response', 'Age',
#        'Customer_Tenure_Days', 'Total_Spending', 'Total_Children',
#        'Living_with'],
#       dtype='object')

# %%
cols=["Income","Recency","Age","Total_Spending","Total_Children"]

# %%
# relative plots of features using pairplots - they are like scatterplot of multiple features with eachother
sns.pairplot(df_cleaned[cols])

# %%
# Removing outliers
print("data size with outliers:",len(df_cleaned))
df_cleaned=df_cleaned[ (df_cleaned["Age"]<90) ]
df_cleaned=df_cleaned[ (df_cleaned["Income"]<600_000) ]
print("data size without outliers:",len(df_cleaned))
# Out:
# data size with outliers: 2240
# data size without outliers: 2236

# %% [markdown]
# ### Heatmap

# %%
corr=df_cleaned.corr(numeric_only=True)
corr
# Out:
#                         Income   Recency  NumDealsPurchases  NumWebPurchases  \
# Income                1.000000  0.007829          -0.107169         0.450584
# Recency               0.007829  1.000000          -0.000638        -0.010776
# NumDealsPurchases    -0.107169 -0.000638           1.000000         0.233971
# NumWebPurchases       0.450584 -0.010776           0.233971         1.000000
# NumCatalogPurchases   0.693781  0.025226          -0.008510         0.378049
# NumStorePurchases     0.628075  0.000771           0.068418         0.502227
# NumWebVisitsMonth    -0.646382 -0.021850           0.347216        -0.056204
# Complain             -0.027871  0.005361           0.003636        -0.013250
# Response              0.161121 -0.198781           0.002017         0.148390
# Age                   0.198835  0.019396           0.068286         0.153873
# Customer_Tenure_Days -0.023677  0.024238           0.218009         0.191211
# ...

# %%
plt.figure(figsize=(10,7))
sns.heatmap(corr,annot=True,annot_kws={"size":6},cmap="coolwarm")
# Out:
# <Axes: >

# %%
# Encoding
from sklearn.preprocessing import OrdinalEncoder,OneHotEncoder,StandardScaler

# %%
df_cleaned.columns
# Out:
# Index(['Education', 'Income', 'Recency', 'NumDealsPurchases',
#        'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases',
#        'NumWebVisitsMonth', 'Complain', 'Response', 'Age',
#        'Customer_Tenure_Days', 'Total_Spending', 'Total_Children',
#        'Living_with'],
#       dtype='object')

# %%
cat_cols=['Education','Living_with']

# %%
ohe=OneHotEncoder() # no need to use drop_first=True in clustering
enc_cols=ohe.fit_transform(df_cleaned[cat_cols])
enc_df=pd.DataFrame(enc_cols.toarray(),columns=ohe.get_feature_names_out(cat_cols),index=df_cleaned.index) # toarray()-sparse data into numpy array

# %%
df_encoded=pd.concat([df_cleaned.drop(columns=cat_cols),enc_df],axis=1)

# %%
df_encoded.shape
# Out:
# (2236, 18)

# %%
df_encoded.head()
# Out:
#     Income  Recency  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# 0  58138.0       58                  3                8                   10
# 1  46344.0       38                  2                1                    1
# 2  71613.0       26                  1                8                    2
# 3  26646.0       26                  2                2                    0
# 4  58293.0       94                  5                5                    3
#
#    NumStorePurchases  NumWebVisitsMonth  Complain  Response  Age  \
# 0                  4                  7         0         1   69
# 1                  2                  5         0         0   72
# 2                 10                  4         0         0   61
# 3                  4                  6         0         0   42
# 4                  6                  5         0         0   45
#
#    Customer_Tenure_Days  Total_Spending  Total_Children  Education_Graduation  \
# ...

# %%
X=df_encoded

# %%
# Scaling
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[ 0.28894655,  0.30685572,  0.34873831, ..., -0.35877969,
#          1.3476353 , -1.3476353 ],
#        [-0.262003  , -0.38397129, -0.16869955, ..., -0.35877969,
#          1.3476353 , -1.3476353 ],
#        [ 0.91842301, -0.7984675 , -0.68613742, ..., -0.35877969,
#         -0.74204052,  0.74204052],
#        ...,
#        [ 0.234898  ,  1.44672029, -0.68613742, ..., -0.35877969,
#          1.3476353 , -1.3476353 ],
#        [ 0.80780332, -1.42021181, -0.16869955, ..., -0.35877969,
#         -0.74204052,  0.74204052],
#        [ 0.04280841, -0.31488859,  0.34873831, ..., -0.35877969,
#         -0.74204052,  0.74204052]])

# %% [markdown]
# ### Visualize

# %%
from sklearn.decomposition import PCA

# %%
# for visualizing our data we are converting it into 2D using PCA
pca=PCA(n_components=3)
X_pca=pca.fit_transform(X_scaled)

# %%
pca.explained_variance_ratio_   # every new feature capturing how vairance/eigen value
# Out:
# array([0.23163158, 0.11385454, 0.10405815])

# %%
fig=plt.figure(figsize=(8,6))
ax=fig.add_subplot(111,projection="3d")

ax.scatter(X_pca[:,0],X_pca[:,1],X_pca[:,2])
ax.set_xlabel("PC1")
ax.set_ylabel("PC2")
ax.set_zlabel("PC3")
ax.set_title("3D Projection")
# Out:
# Text(0.5, 0.92, '3D Projection')

# %% [markdown]
# ### Analyze K value

# %%
# !pip install kneed

# %%
from sklearn.cluster import KMeans,AgglomerativeClustering
from kneed import KneeLocator

# %%
wcss=[]
for k in range(1,11):
    kmean=KMeans(n_clusters=k,random_state=42)
    kmean.fit_predict(X_pca)
    wcss.append(kmean.inertia_)

# %%
plt.plot(range(1,11),wcss,marker="o")
plt.xlabel("k")
plt.ylabel("wcss/Inertia")
plt.title("wcss vs k")
# Out:
# Text(0.5, 1.0, 'wcss vs k')

# %%
knee=KneeLocator(range(1,11),wcss,curve="convex",direction="decreasing")
optimal_k=knee.knee
print("Best value of k:",optimal_k)
# Out:
# Best value of k: 4

# %% [markdown]
# ### Using Sihouette Score

# %%
from sklearn.metrics import silhouette_score

# %%
scores=[]
for k in range(2,11):
    kmean=KMeans(n_clusters=k,random_state=42)
    labels=kmean.fit_predict(X_pca)
    score=silhouette_score(X_pca,labels)
    scores.append(score)

# %%
plt.plot(range(2,11),scores,marker="o")
plt.xlabel("k")
plt.ylabel("Sihouette Score")
# Out:
# Text(0, 0.5, 'Sihouette Score')

# %% [markdown]
# ### Clustering

# %%
# KMeans
kmean=KMeans(n_clusters=4,random_state=42)
labels_kmean=kmean.fit_predict(X_pca)

# %%
fig=plt.figure(figsize=(8,6))
ax=fig.add_subplot(111,projection="3d")
ax.scatter(X_pca[:,0],X_pca[:,1],X_pca[:,2],c=labels_kmean)

# %%
# Agglomerative Clustering
agg_cls=AgglomerativeClustering(n_clusters=4,linkage="ward")
labels_agg=agg_cls.fit_predict(X_pca)

# %%
fig=plt.figure(figsize=(8,6))
ax=fig.add_subplot(111,projection="3d")
ax.scatter(X_pca[:,0],X_pca[:,1],X_pca[:,2],c=labels_agg)

# %% [raw]
# # we doesnot use DBSCAN here as it it best for anomaly detection and here it will create more than 30 clusters here on this dataset

# %% [markdown]
# ### Characterization of clusters

# %%
X["clusters"]=labels_agg

# %%
X.head()
# Out:
#     Income  Recency  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# 0  58138.0       58                  3                8                   10
# 1  46344.0       38                  2                1                    1
# 2  71613.0       26                  1                8                    2
# 3  26646.0       26                  2                2                    0
# 4  58293.0       94                  5                5                    3
#
#    NumStorePurchases  NumWebVisitsMonth  Complain  Response  Age  \
# 0                  4                  7         0         1   69
# 1                  2                  5         0         0   72
# 2                 10                  4         0         0   61
# 3                  4                  6         0         0   42
# 4                  6                  5         0         0   45
#
#    Customer_Tenure_Days  Total_Spending  Total_Children  Education_Graduation  \
# ...

# %%
plt=["red","blue","yellow","green"]
sns.countplot(x=X["clusters"],palette=plt,hue=X["clusters"])
# Out:
# <Axes: xlabel='clusters', ylabel='count'>

# %%
# Income vs Total Spending
sns.scatterplot(x=X["Total_Spending"],y=X["Income"],hue=X["clusters"],palette=plt)
# Out:
# <Axes: xlabel='Total_Spending', ylabel='Income'>

# %%
#cluster 0:Red    ----> low/moderate spending  , low/moderate income
#cluster 1:Blue   ----> high spending          , high income
#cluster 2:Yellow ----> low spending           , low income
#cluster 3:Green  ----> high spending          , moderate/high income

# %%
X.columns
# Out:
# Index(['Income', 'Recency', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'Complain', 'Response', 'Age', 'Customer_Tenure_Days', 'Total_Spending',
#        'Total_Children', 'Education_Graduation', 'Education_Postgraduate',
#        'Education_Undergraduate', 'Living_with_Alone', 'Living_with_Partner',
#        'clusters'],
#       dtype='object')

# %%
### Cluster Summary
cluster_summary=X.groupby("clusters").mean()
cluster_summary
# Out:
#                 Income    Recency  NumDealsPurchases  NumWebPurchases  \
# clusters
# 0         39680.580110  48.914917           2.594475         3.153591
# 1         72808.445693  49.202247           1.958801         5.687266
# 2         36960.143018  48.319820           2.594595         2.713964
# 3         70722.681303  50.504249           1.855524         5.790368
#
#           NumCatalogPurchases  NumStorePurchases  NumWebVisitsMonth  Complain  \
# clusters
# 0                    0.969061           4.143646           6.307182  0.011050
# 1                    5.498127           8.659176           3.580524  0.005618
# 2                    0.837838           3.623874           6.659910  0.011261
# 3                    5.014164           8.430595           3.728045  0.005666
#
#           Response        Age  Customer_Tenure_Days  Total_Spending  \
# clusters
# 0         0.076243  55.669613            342.939227      221.955801
# ...

# %% [markdown]
# # Insights

# %% [markdown]
# ## Business Insights
#
# ### Cluster 0 – Family Shoppers
# - Low Income, Poor reponse, more children, have partners, more website visits, less store, web and catalog purchase
# - Customers are price-sensitive and prefer value-for-money purchases.
# - Discounts and family bundle offers are likely to improve engagement.
#
# ### Cluster 1 – Loyal Customers
# - Very High Income, High age, average reponse, fewer children, alone, less website visits, high store, web and catalog purchase
# - Customers show consistent purchasing behavior and moderate to high spending.
# - Loyalty programs and personalized recommendations can improve retention.
#
# ### Cluster 2 – Digital Browsers
# - Very Low Income, Average reponse, more children, have partners, more website visits, very less store, web and catalog purchase
# - Customers are highly active online but spend relatively less.
# - Sales and Heavy discounts and coupons can increase conversions.
#
# ### Cluster 3 – High-Value Customers
# - High Income, slighlty high age, best reponse, fewer children, alone, less website visits, high store, web and catalog purchase
# - This segment contributes the highest revenue and spending.
# - Premium services and exclusive offers should be prioritized for these customers.
